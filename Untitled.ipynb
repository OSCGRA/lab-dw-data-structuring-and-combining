# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv")
df=data.copy()
data2=pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv")
df2=data2.copy()
data3=pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv")
df3=data3.copy()
df3.1=data3.copy()

# %%
df3_1=data3.copy()
df3_1.sample(6)
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 770   WQ13284  California              8395.272249               College
# 1570  ZM33786     Arizona             37150.829450  High School or Below
# 1605  OE15600  California              2544.969754               College
# 4695  QL46987      Oregon              9082.833891              Bachelor
# 6722  HX41374  California             15234.745900  High School or Below
# 5985  DM77491      Oregon              7416.466665              Bachelor
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# 770       M   62989                    71                          1
# 1570      F   17774                   108                          0
# 1605      M   91169                    65                          0
# 4695      F   34430                   117                          0
# 6722      M   72988                   127                          0
# ...

# %%
df.rename(columns={"ST": "state"}, inplace = True)
df2.rename(columns={"ST": "state"}, inplace = True)
df.columns = df.columns.str.lower().str.replace(" ","_")
df2.columns = df.columns.str.lower().str.replace(" ","_") 
df3_1.columns = df.columns.str.lower().str.replace(" ","_")

# %%
df3_1
# Out:
#      customer       state        gender             education  \
# 0     SA25987  Washington   3479.137523  High School or Below
# 1     TB86706     Arizona   2502.637401                Master
# 2     ZL73902      Nevada   3265.156348              Bachelor
# 3     KX23516  California   4455.843406  High School or Below
# 4     FN77294  California   7704.958480  High School or Below
# ...       ...         ...           ...                   ...
# 7065  LA72316  California  23405.987980              Bachelor
# 7066  PK87824  California   3096.511217               College
# 7067  TD14365  California   8163.890428              Bachelor
# 7068  UP19263  California   7524.442436               College
# 7069  Y167826  California   2611.836866               College
#
#      customer_lifetime_value  income  monthly_premium_auto  \
# 0                          M       0                   104
# 1                          M       0                    66
# ...
